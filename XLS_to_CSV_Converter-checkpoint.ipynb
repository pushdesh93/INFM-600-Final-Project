# %%
import pandas as pd

# %%
xlsfiles={"How to treat boils and cysts.xls","How to treat burn.xls","How to treat corns and calluses.xls"
         ,"Manage excessive sweating.xls","Prevent and treat blisters.xls","Prevent and treat nail fungus.xls","Ringworm.xls"}

# %%
df_test = pd.read_excel(r"Home treatments for warts.xls",sheetname=None)
df_watch_time = df_test['Watch time']
df_traffic_source = df_test['Traffic source']
df_playback_location = df_test['Playback location']
df_demographics = df_test['Demographics']

# %%
for file in xlsfiles:
    df1 = pd.read_excel(file,sheetname=None)
    df_watch_time = df_watch_time.append(df1['Watch time'])
    
    df_traffic_source = df_traffic_source.append(df1['Traffic source'])
    df_playback_location = df_playback_location.append(df1['Playback location'])
    df_demographics = df_demographics.append(df1['Demographics'])

# %%
df_watch_time['Video title'].unique()
# Out:
# array(['Home treatment for warts', 'How to treat corns and calluses',
#        'Is it ringworm? Signs and symptoms',
#        'How to treat a first degree (minor) burn',
#        'How to manage excessive sweating',
#        'How to prevent and treat nail fungus',
#        'How to treat boils and styes', 'How to prevent and treat blisters'], dtype=object)

# %%
df_watch_time.to_csv('Watch time.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-b3f2989bc7e5> in <module>()
# ----> 1 df_watch_time.to_csv('Watch time.csv')
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# PermissionError: [Errno 13] Permission denied: 'Watch time.csv'

# %%
df_traffic_source=pd.read_csv(r'Traffic source.csv',header=True,encoding='utf8')
df_playback_location=pd.read_csv(r'Playback location.csv',encoding='utf8',header=True)
df_demographics=pd.read_csv(r'Demogrpahics.csv',encoding='utf8',header=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-dac7bd4eda17> in <module>()
# ----> 1 df_traffic_source=pd.read_csv(r'Traffic source.csv',header=True,encoding='utf8')
#       2 df_playback_location=pd.read_csv(r'Playback location.csv',encoding='utf8',header=True)
#       3 df_demographics=pd.read_csv(r'Demogrpahics.csv',encoding='utf8',header=True)
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     757         # might mutate self.engine
#     758         self.engine = self._check_file_or_buffer(f, engine)
# --> 759         self.options, self.engine = self._clean_options(options, engine)
#     760
#     761         if 'has_index_names' in kwds:
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\parsers.py in _clean_options(self, options, engine)
#     915         keep_default_na = result.pop('keep_default_na')
#     916
# --> 917         _validate_header_arg(options['header'])
#     918
#     919         depr_warning = ''
#
# C:\Users\pushd\Anaconda3\lib\site-packages\pandas\io\common.py in _validate_header_arg(header)
#     140 def _validate_header_arg(header):
#     141     if isinstance(header, bool):
# --> 142         raise TypeError("Passing a bool to header is invalid. "
#     143                         "Use header=None for no header or "
#     144                         "header=int or list-like of ints to specify "
#
# TypeError: Passing a bool to header is invalid. Use header=None for no header or header=int or list-like of ints to specify the row(s) making up the column names

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g=sns.FacetGrid(data=df_traffic_source,row='Traffic source type',size=5)
g.map(plt.hist,)

# %%
df_traffic_source=df_traffic_source.reset_index()

# %%
df_demographics=df_demographics.groupby(['Viewer gender','Viewer age']).sum()

# %%
df_playback_location=df_playback_location.groupby(['Geography','Playback location type']).sum()

# %%
df_traffic_source=df_traffic_source.groupby(['Geography','Traffic source type','Date']).sum()

# %%
df_traffic_source.to_csv('Traffic_Source_New')
df_playback_location.to_csv('Playback_Location_New')
df_demographics=df_demographics.to_csv('Demographics_New')
